# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

import cv2

path = '/content/drive/MyDrive/OpenCV-Images/dog.JPG'

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread(path, cv2.IMREAD_COLOR)
cv2_imshow(img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF3186CD0>

# %% [markdown]
# ### **1) Draw a Line**
#
# line(image, start_point, end_point, color, thickness)

# %%
# Make copy of the image
imageLine = img.copy()

# Draw the image from point A to B
pointA = (200,80)
pointB = (450,80)

cv2.line(imageLine, pointA, pointB, (255, 255, 0), thickness=3)

cv2_imshow(imageLine)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF309CB10>
# -1

# %% [markdown]
# ### **2) Draw a Circle**
#
# circle(image, center_coordinates, radius, color, thickness)

# %%
# Make a copy of image
imageCircle = img.copy()

# define the center of circle
circle_center = (415,190)

# define the radius of the circle
radius =100

#  Draw a circle using the circle() Function
cv2.circle(imageCircle, circle_center, radius, (0, 0, 255), thickness=3, lineType=cv2.LINE_AA)

# Display the result
cv2_imshow(imageCircle)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF30C0290>
# -1

# %% [markdown]
# ### **3) Draw a Filled Circle**

# %%
# make a copy of the original image
imageFilledCircle = img.copy()

# define center of the circle
circle_center = (415,190)

# define the radius of the circle
radius =100

# draw the filled circle on input image
cv2.circle(imageFilledCircle, circle_center, radius, (255, 0, 0), thickness=-1, lineType=cv2.LINE_AA)

# display the output image
cv2_imshow(imageFilledCircle)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF30CD290>
# -1

# %% [markdown]
# ### **4) Draw a Rectangle**
#
# - rectangle(image, start_point, end_point, color, thickness)

# %%
# make a copy of the original image
imageRectangle = img.copy()

# define the starting and end points of the rectangle
start_point =(300,115)
end_point =(475,225)

# draw the rectangle
cv2.rectangle(imageRectangle, start_point, end_point, (0, 0, 255), thickness= 3, lineType=cv2.LINE_8)

# display the output
cv2_imshow(imageRectangle)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF30C0890>
# -1

# %% [markdown]
# ### 5) Draw an Ellipse**
#
# ellipse(image, centerCoordinates, axesLength, angle, startAngle, endAngle, color, thickness)

# %%
# make a copy of the original image
imageEllipse = img.copy()

# define the center point of ellipse
ellipse_center = (415,190)

# define the major and minor axes of the ellipse
axis1 = (100,50)
axis2 = (125,50)

# draw the ellipse
# Horizontal
cv2.ellipse(imageEllipse, ellipse_center, axis1, 0, 0, 360, (255, 0, 0), thickness=3)

#Vertical
cv2.ellipse(imageEllipse, ellipse_center, axis2, 90, 0, 360, (0, 0, 255), thickness=3)

# display the output
cv2_imshow(imageEllipse)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF1890710>
# -1

# %% [markdown]
# ### **6) Draw a Half-Ellipse**

# %%
# make a copy of the original image
halfEllipse = img.copy()

# define the center of half ellipse
ellipse_center = (415,190)

# define the axis point
axis1 = (100,50)

# draw the Incomplete/Open ellipse, just a outline
cv2.ellipse(halfEllipse, ellipse_center, axis1, 0, 180, 360, (255, 0, 0), thickness=3)

# if you want to draw a Filled ellipse, use this line of code
cv2.ellipse(halfEllipse, ellipse_center, axis1, 0, 0, 180, (0, 0, 255), thickness=-2)

# display the output
cv2_imshow(halfEllipse)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF1840090>
# -1

# %% [markdown]
# ### **7) Adding Text**
#
# putText(image, text, org, font, fontScale, color)

# %%
# make a copy of the original image
imageText = img.copy()

# let's write the text you want to put on the image
text = 'I am a Happy dog!'

# org: Where you want to put the text
org = (50,350)

# write the text on the input image
cv2.putText(imageText, text, org, fontFace = cv2.FONT_HERSHEY_COMPLEX, fontScale = 1.5, color = (250,225,100))

# display the output image with text over it
cv2_imshow(imageText)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=635x424 at 0x7FBAF183D910>

# %% [markdown]
# ### **Reference**
#
# - https://learnopencv.com/annotating-images-using-opencv/
