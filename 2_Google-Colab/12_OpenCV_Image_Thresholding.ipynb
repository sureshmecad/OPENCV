# %% [markdown]
# - Global Thresholding
#
# - Binary Thresholding
#
# - Inverse-Binary Thresholding
#
# - Truncate Thresholding
#
# - Threshold to Zero
#
# - Inverted Threshold to Zero

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

import cv2

path = '/content/drive/MyDrive/OpenCV-Images/Digit.JPG'

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread(path, cv2.IMREAD_COLOR)
cv2_imshow(img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=479x361 at 0x7FD6E26503D0>

# %% [markdown]
# #### **Global Thresholding (Binary Thresholding)**

# %%
# Read image
src = cv2.imread(path, cv2.IMREAD_GRAYSCALE);

# Basic threhold example
th, dst = cv2.threshold(src, 0, 255, cv2.THRESH_BINARY);
cv2.imwrite("opencv-threshold-example.jpg", dst);

# Thresholding with maxValue set to 128
th, dst = cv2.threshold(src, 0, 128, cv2.THRESH_BINARY);
cv2.imwrite("opencv-thresh-binary-maxval.jpg", dst);

# Thresholding with threshold value set 127
th, dst = cv2.threshold(src,127,255, cv2.THRESH_BINARY);
cv2.imwrite("opencv-thresh-binary.jpg", dst);

# Thresholding using THRESH_BINARY_INV
th, dst = cv2.threshold(src,127,255, cv2.THRESH_BINARY_INV);
cv2.imwrite("opencv-thresh-binary-inv.jpg", dst);

# Thresholding using THRESH_TRUNC
th, dst = cv2.threshold(src,127,255, cv2.THRESH_TRUNC);
cv2.imwrite("opencv-thresh-trunc.jpg", dst);

# Thresholding using THRESH_TOZERO
th, dst = cv2.threshold(src,127,255, cv2.THRESH_TOZERO);
cv2.imwrite("opencv-thresh-tozero.jpg", dst);

# Thresholding using THRESH_TOZERO_INV
th, dst = cv2.threshold(src,127,255, cv2.THRESH_TOZERO_INV);
cv2.imwrite("opencv-thresh-to-zero-inv.jpg", dst);

# %% [markdown]
# #### **1) Binary Thresholding (THRESH_BINARY)**

# %%
path1 = '/content/drive/MyDrive/OpenCV-Images/Digit1.JPG'

# %%
# Thresholding rule
# Binary Threshold
if src(x,y) > thresh
  dst(x,y) = maxValue
else
  dst(x,y) = 0

# %% [markdown]
#      # Basic threhold example
#      th, dst = cv2.threshold(src, 0, 255, cv2.THRESH_BINARY);
#      cv2.imwrite("opencv-threshold-example.jpg", dst);

# %%
# Read image
src = cv2.imread(path1, cv2.IMREAD_GRAYSCALE)
cv2_imshow(src)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E0CE2AD0>

# %%
# Set threshold and maxValue
thresh = 0
maxValue = 255

# Basic threshold example
th, dst = cv2.threshold(src, thresh, maxValue, cv2.THRESH_BINARY);
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E0CB15D0>

# %%
# Set threshold and maxValue
thresh = 127
maxValue = 255

# Basic threshold example
th, dst = cv2.threshold(src, thresh, maxValue, cv2.THRESH_BINARY);
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E0CDD090>

# %%
# Set threshold and maxValue
thresh = 0
maxValue = 128

# Basic threshold example
th, dst = cv2.threshold(src, thresh, maxValue, cv2.THRESH_BINARY);
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E25753D0>

# %% [markdown]
# #### **2) Inverse-Binary Thresholding (THRESH_BINARY_INV)**
#
# - Inverse-Binary Thresholding is just the opposite of Binary Thresholding. The destination pixel is set to:
#
#  - zero, if the corresponding source pixel is greater than the threshold
#
#  - **maxValue**, if the source pixel is less than the threshold

# %% [markdown]
#      # Thresholding rule
#      # Inverse Binary Threshold
#      if src(x,y) > thresh
#        dst(x,y) = 0
#      else
#        dst(x,y) = maxValue

# %%
# Set threshold and maxValue
thresh = 127
maxValue = 0

th, dst = cv2.threshold(src, thresh, maxValue, cv2.THRESH_BINARY_INV)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E0CD4ED0>

# %% [markdown]
# #### **3) Truncate Thresholding (THRESH_TRUNC)**
#
# - The destination pixel is set to the threshold **(thresh)**, if the source pixel value is greater than the threshold.
#
# - Otherwise, it is set to the source pixel value
#
# - The maxValue is ignored

# %% [markdown]
#      # Thresholding rule
#      # Truncate Threshold
#      if src(x,y) > thresh
#        dst(x,y) = thresh
#      else
#        dst(x,y) = src(x,y)

# %%
# Set threshold and maxValue
thresh = 127
maxValue = 255

th, dst = cv2.threshold(src, thresh, maxValue, cv2.THRESH_TRUNC)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E0CB6550>

# %% [markdown]
# - All values above the threshold (127) are set to 127
#
# - All values less than or equal to 127 are unchanged
#
# - The  maxValue is ignored.

# %% [markdown]
# #### **4) Threshold to Zero (THRESH_TOZERO)**
#
# - The destination pixel value is set to the pixel value of the corresponding source , if the source pixel value is greater than the threshold.
#
# - Otherwise, it is set to zero
#
# - The **maxValue** is ignored

# %% [markdown]
#      # Thresholding rule
#      # Threshold to Zero
#      if src(x,y) > thresh
#        dst(x,y) = src(x,y)
#      else
#        dst(x,y) = 0

# %%
# Set threshold and maxValue
thresh = 127
maxValue = 255

th, dst = cv2.threshold(src, thresh, maxValue, cv2.THRESH_TOZERO)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E0CE2610>

# %% [markdown]
# #### **5) Inverted Threshold to Zero (THRESH_TOZERO_INV)**
#
# - The destination pixel value is set to zero, if the source pixel value is greater than the threshold.
#
# - Otherwise, it is set to the source pixel value
#
# - The **maxValue** is ignored

# %% [markdown]
#      # Thresholding rule
#      # Inverted Threshold to Zero
#      if src(x,y) > thresh
#        dst(x,y) = 0
#      else
#        dst(x,y) = src(x,y)

# %%
# Set threshold and maxValue
thresh = 127
maxValue = 255

th, dst = cv2.threshold(src, thresh, maxValue, cv2.THRESH_TOZERO_INV)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=509x380 at 0x7FD6E0CD4090>

# %% [markdown]
# #### **Reference**
#
# - https://learnopencv.com/opencv-threshold-python-cpp/
