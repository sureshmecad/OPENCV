# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

import cv2

path = '/content/drive/MyDrive/OpenCV-Images/Ship.JPG'

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread(path, cv2.IMREAD_COLOR)
cv2_imshow(img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=687x456 at 0x7F866CB78110>

# %% [markdown]
# #### **1) Image Rotation**

# %%
# Dividing height and width by 2 to get the center of the image
height, width = img.shape[:2]
center = (width/2, height/2)

# %% [markdown]
# #### **getRotationMatrix2D(center, angle, scale)**
#
# **center:** the center of rotation for the input image
#
# **angle:** the angle of rotation in degrees
#
# **scale:** an isotropic scale factor which scales the image up or down according to the value provided

# %%
# the above center is the center of rotation axis
# use cv2.getRotationMatrix2D() to get the rotation matrix
rotate_matrix = cv2.getRotationMatrix2D(center=center, angle=45, scale=1)

# %% [markdown]
# #### **warpAffine(src, M, dsize[, dst[, flags[, borderMode[, borderValue]]]])**
#
# **src:** the source mage
#
# **M:** the transformation matrix
#
# **dsize:** size of the output image
#
# **dst:** the output image
#
# **flags:** combination of interpolation methods such as INTER_LINEAR or INTER_NEAREST
#
# **borderMode:** the pixel extrapolation method
#
# **borderValue:** the value to be used in case of a constant border, has a default value of 0

# %%
# Rotate the image using cv2.warpAffine
rotated_image = cv2.warpAffine(src=img, M=rotate_matrix, dsize=(width, height))

# %% [markdown]
#      # visualize the original and the rotated image
#      cv2_imshow('Original image', image)
#      cv2_imshow('Rotated image', rotated_image)
#
#      # wait indefinitely, press any key on keyboard to exit
#      cv2.waitKey(0)
#
#      # write the output, the rotated image to disk
#      cv2.imwrite('rotated_image.jpg', rotated_image)

# %%
# visualize the original and the rotated image
cv2_imshow(img)
cv2_imshow(rotated_image)

# wait indefinitely, press any key on keyboard to exit
cv2.waitKey(0)

# write the output, the rotated image to disk
cv2.imwrite('rotated_image.jpg', rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=687x456 at 0x7F865BF23910>
# <PIL.Image.Image image mode=RGB size=687x456 at 0x7F865BF23910>
# True

# %% [markdown]
# #### **2) Translation of Images**

# %%
# get tx and ty values for translation
# you can specify any value of your choice
tx, ty = width / 4, height / 4

# create the translation matrix using tx and ty, it is a NumPy array
translation_matrix = np.array([[1, 0, tx], [0, 1, ty]], dtype=np.float32)

# %%
# apply the translation to the image
translated_image = cv2.warpAffine(src=img, M=translation_matrix, dsize=(width, height))

# %%
# display the original and the Translated images
cv2_imshow(translated_image)
cv2_imshow(img)

cv2.waitKey(0)

# save the translated image to disk
cv2.imwrite('translated_image.jpg', translated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=687x456 at 0x7F865BF23A50>
# <PIL.Image.Image image mode=RGB size=687x456 at 0x7F865BF23A50>
# True
