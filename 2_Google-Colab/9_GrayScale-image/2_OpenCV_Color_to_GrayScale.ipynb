# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

import cv2

path = '/content/drive/MyDrive/seedling classification for bootcamp/train_plant_classification/Charlock/0a7e1ca41.png'

# %%
img = cv2.imread(path) 
plt.figure(figsize = (15,10))
plt.imshow(img)

# %% [markdown]
# #### **Change colored image to grayscale**

# %% [markdown]
# ##### **Jupyter**
#
#      gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#
#      cv2.imshow('zebra',gray)
#
#      cv2.waitKey(0)
#
#      cv2.destroyAllWindows()
#
# --------------------------------------------------------------------------------
#
# ##### **Colab**
#
#      img_grayscale = cv2.imread("geeksforgeeks.jpg", cv2.IMREAD_GRAYSCALE)
#
#                               (or)
#
#      img_grayscale = cv2.imread("geeksforgeeks.jpg", 0)
#
#                               (or)
#
#      img_grayscale = cv2.cvtColor("geeksforgeeks.jpg", cv2.COLOR_BGR2GRAY)

# %% [markdown]
# #### **Method 1**

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread(path, 0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=484x484 at 0x7F298AAAFF50>

# %% [markdown]
# #### **Method 2**

# %%
from google.colab.patches import cv2_imshow
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=484x484 at 0x7F298AB28E90>

# %% [markdown]
# - Additionally, you can do its **reverse operation** too i.e. to **convert a grayscale image into a colored one.**
#
# - To change the **gray-scale image into a colored one**, instead of **cv2.COLOR_BGR2GRAY, use cv2.COLOR_GRAY2RGB**.
