# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing libraries
import cv2
import numpy as np

from google.colab.patches import cv2_imshow

# %%
path = '/content/drive/MyDrive/OpenCV-Images/tomoto.JPG'

image = cv2.imread(path)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=424x284 at 0x7F5080BF2C50>

# %% [markdown]
# - **Grayscaling** is the process of **converting** an image from other color spaces e.g. **RGB, CMYK, HSV, etc.** to **shades of gray**. It varies between **complete black and complete white.**
#
# #### **Importance of grayscaling**
#
#  - **Dimension reduction:** For example, In **RGB** images there are **three color channels** and has **three dimensions** while **grayscale** images are **single-dimensional.**
#
#  - **Reduces model complexity:** Consider training neural article on **RGB** images of **10x10x3** pixel. The input layer will have **300** input nodes. On the other hand, the same neural network will need only **100** input nodes for **grayscale** images.
#
#  - **For other algorithms to work:** Many algorithms are customized to work only on grayscale images e.g. Canny edge detection function pre-implemented in OpenCV library works on Grayscale images only.

# %% [markdown]
# #### **Three Methods for Grayscale image**
#
# --------------------------------------------------------------------------------
#
#      # Use the cvtColor() function to grayscale the image
#      gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#
#      cv2_imshow(gray_image) # Grayscale
#      cv2.waitKey(0)
#
# -------------------------------------------------------------------------------
#
#      # Use the second argument or (flag value) zero that specifies the image is to be read in grayscale mode
#      img = cv2.imread(path, 0)
#
#      cv2_imshow(img) # Grayscale Image
#      cv2.waitKey(0)
#
#      # Window shown waits for any key pressing event
#      cv2.destroyAllWindows()
#
# ----------------------------------------------------------------------------
#
#      # Obtain the dimensions of the image array using the shape method
#      (row, col) = img.shape[0:2]
#
#      # Take the average of pixel values of the BGR Channels to convert the colored image to grayscale image
#      for i in range(row):
#          for j in range(col):
#              # Find the average of the BGR pixel values
#              img[i, j] = sum(img[i, j]) * 0.33
#
#      cv2_imshow(img) # Grayscale Image
#      cv2.waitKey(0)
#
#      # Window shown waits for any key pressing event
#      cv2.destroyAllWindows()

# %% [markdown]
# #### **Method 1:**
#
# - Using the **cv2.cvtColor()** function

# %%
# Load the input image
image = cv2.imread(path)
cv2_imshow(image) # Original
cv2.waitKey(0)
 
# Use the cvtColor() function to grayscale the image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
 
cv2_imshow(gray_image) # Grayscale
cv2.waitKey(0) 
 
# Window shown waits for any key pressing event
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=424x284 at 0x7F507F2810D0>
# <PIL.Image.Image image mode=L size=424x284 at 0x7F507F281C10>

# %% [markdown]
# #### **Method 2:**
#
# - Using the **cv2.imread()** function with **flag = zero**

# %%
# Use the second argument or (flag value) zero that specifies the image is to be read in grayscale mode
img = cv2.imread(path, 0)
 
cv2_imshow(img) # Grayscale Image
cv2.waitKey(0)
 
# Window shown waits for any key pressing event
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=424x284 at 0x7F5080AFF950>

# %% [markdown]
# #### **Method 3:**
#
# - Using the pixel manipulation **(Average method)**

# %%
# Load the input image
img = cv2.imread(path)
 
# Obtain the dimensions of the image array using the shape method
(row, col) = img.shape[0:2]
 
# Take the average of pixel values of the BGR Channels to convert the colored image to grayscale image
for i in range(row):
    for j in range(col):
        # Find the average of the BGR pixel values
        img[i, j] = sum(img[i, j]) * 0.33
 
cv2_imshow(img) # Grayscale Image
cv2.waitKey(0)
 
# Window shown waits for any key pressing event
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=424x284 at 0x7F50900D7090>
